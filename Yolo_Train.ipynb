# %%
# Download Pre-trained YoloV2 weights
! wget https://pjreddie.com/media/files/darknet19_448.conv.23
# Out:
# --2019-08-22 10:55:30--  https://pjreddie.com/media/files/darknet19_448.conv.23
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79327120 (76M) [application/octet-stream]
# Saving to: ‘darknet19_448.conv.23’
#
# darknet19_448.conv. 100%[===================>]  75.65M   994KB/s    in 59s
#
# 2019-08-22 10:56:31 (1.29 MB/s) - ‘darknet19_448.conv.23’ saved [79327120/79327120]

# %%
ls darknet
# Out:
# darknet*

# %%
import os
os.chdir('darknet')

# %%
! cp -v../darknet19_448.conv.23 .

# %%
ls
# Out:
# 3rdparty/       darknet*                Makefile
# appveyor.yml    darknet19_448.conv.23   net_cam_v3.sh*
# backup/         DarknetConfig.cmake.in  obj/
# bad_label.list  darknet.py              README.md
# build/          darknet_video.py        results/
# build.ps1*      data/                   scripts/
# build.sh*       image_yolov2.sh*        src/
# cfg/            image_yolov3.sh*        video_v2.sh*
# chart.png       include/                video_yolov3.sh*
# cmake/          json_mjpeg_streams.sh*
# CMakeLists.txt  LICENSE

# %%
# !rm -r data

# %%
cp -rv ../data .
# Out:
# '../data' -> './data'
# '../data/obj' -> './data/obj'
# '../data/obj/1.png' -> './data/obj/1.png'
# '../data/obj/2.png' -> './data/obj/2.png'
# '../data/obj/3.png' -> './data/obj/3.png'
# '../data/obj/4.png' -> './data/obj/4.png'
# '../data/obj/5.png' -> './data/obj/5.png'
# '../data/obj/6.png' -> './data/obj/6.png'
# '../data/obj/7.png' -> './data/obj/7.png'
# '../data/obj/8.png' -> './data/obj/8.png'
# '../data/obj/9.png' -> './data/obj/9.png'
# '../data/obj/10.png' -> './data/obj/10.png'
# '../data/obj/11.png' -> './data/obj/11.png'
# '../data/obj/12.png' -> './data/obj/12.png'
# '../data/obj/13.png' -> './data/obj/13.png'
# '../data/obj/14.png' -> './data/obj/14.png'
# '../data/obj/15.png' -> './data/obj/15.png'
# '../data/obj/16.png' -> './data/obj/16.png'
# '../data/obj/17.png' -> './data/obj/17.png'
# '../data/obj/18.png' -> './data/obj/18.png'
# '../data/obj/19.png' -> './data/obj/19.png'
# '../data/obj/20.png' -> './data/obj/20.png'
# ...

# %%
ls
# Out:
# 3rdparty/     CMakeLists.txt          image_yolov3.sh*        scripts/
# appveyor.yml  darknet19_448.conv.23   include/                src/
# build/        DarknetConfig.cmake.in  json_mjpeg_streams.sh*  video_v2.sh*
# build.ps1*    darknet.py              LICENSE                 video_yolov3.sh*
# build.sh*     darknet_video.py        Makefile
# cfg/          data/                   net_cam_v3.sh*
# cmake/        image_yolov2.sh*        README.md

# %%
! mogrify data/obj/*.png

# %%
# !make
# Out:
# chmod +x *.sh

# %%
ls
# Out:
# 3rdparty/     CMakeLists.txt          image_yolov3.sh*        results/
# appveyor.yml  darknet*                include/                scripts/
# backup/       darknet19_448.conv.23   json_mjpeg_streams.sh*  src/
# build/        DarknetConfig.cmake.in  LICENSE                 video_v2.sh*
# build.ps1*    darknet.py              Makefile                video_yolov3.sh*
# build.sh*     darknet_video.py        net_cam_v3.sh*
# cfg/          data/                   obj/
# cmake/        image_yolov2.sh*        README.md

# %%
! ./darknet detector train cfg/obj.data cfg/yolo-voc.2.0.cfg darknet19_448.conv.23
# Out:
# yolo-voc
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max               2 x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max               2 x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    7 max               2 x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
#    8 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#    9 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   10 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
# ...

# %%
ls
# Out:
# 3rdparty/       darknet*                Makefile
# appveyor.yml    darknet19_448.conv.23   net_cam_v3.sh*
# backup/         DarknetConfig.cmake.in  obj/
# bad_label.list  darknet.py              README.md
# build/          darknet_video.py        results/
# build.ps1*      data/                   scripts/
# build.sh*       image_yolov2.sh*        src/
# cfg/            image_yolov3.sh*        video_v2.sh*
# chart.png       include/                video_yolov3.sh*
# cmake/          json_mjpeg_streams.sh*
# CMakeLists.txt  LICENSE

# %%
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open('data/obj/235.png')
plt.imshow(img)
